# %%
import requests
import pandas as pd                            
import re                                      
import numpy as np
import os
import datetime
from bs4 import BeautifulSoup                          
import json
import seaborn as sns

import matplotlib                              
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42       

# %matplotlib inline

# %%
df = pd.read_csv("Film_Permits.csv")

# %%
df.head()
# Out:
#    EventID        EventType           StartDateTime             EndDateTime  \
# 0   476484  Shooting Permit  04/13/2019 04:00:00 AM  04/13/2019 11:00:00 AM
# 1   476285  Shooting Permit  04/12/2019 01:00:00 PM  04/13/2019 04:00:00 AM
# 2   476282  Shooting Permit  04/12/2019 12:00:00 PM  04/13/2019 03:00:00 AM
# 3   476280  Shooting Permit  04/13/2019 05:00:00 AM  04/13/2019 10:00:00 PM
# 4   476269  Shooting Permit  04/13/2019 06:00:00 AM  04/13/2019 10:00:00 PM
#
#                 EnteredOn                                     EventAgency  \
# 0  04/12/2019 12:34:54 PM  Mayor's Office of Film, Theatre & Broadcasting
# 1  04/11/2019 04:02:54 PM  Mayor's Office of Film, Theatre & Broadcasting
# 2  04/11/2019 03:54:34 PM  Mayor's Office of Film, Theatre & Broadcasting
# 3  04/11/2019 03:54:01 PM  Mayor's Office of Film, Theatre & Broadcasting
# 4  04/11/2019 03:38:02 PM  Mayor's Office of Film, Theatre & Broadcasting
#
#                                          ParkingHeld    Borough  \
# 0     WEST   48 STREET between 6 AVENUE and 7 AVENUE  Manhattan
# 1   83 STREET between DORAN AVENUE and COOPER AVENUE     Queens
# 2   WEST   37 STREET between 10 AVENUE and 11 AVENUE  Manhattan
# 3  NORFOLK STREET between DELANCEY STREET and RIV...  Manhattan
# 4  SUFFOLK STREET between RIVINGTON STREET and DE...  Manhattan
#
#   CommunityBoard(s) PolicePrecinct(s)    Category          SubCategoryName  \
# 0                 5                18  Television                     News
# 1              3, 5          104, 115  Television  Made for TV/mini-series
# 2                 4                10  Television                  Variety
# 3                 3                 7  Commercial                    Promo
# 4                 3                 7  Commercial                    Promo
#
#                     Country    ZipCode(s)
# 0  United States of America  10036, 10105
# 1  United States of America  11372, 11385
# 2  United States of America         10018
# 3  United States of America         10002
# 4  United States of America         10002
